# %% [markdown]
# # Importando bibliotecas necessárias

# %%
import openpyxl
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Carregando o conjunto de dados do Excel

# %%
df = pd.read_excel('vendas_lanchonete2.xlsx')
df = df[['Produto','Quantidade', 'Valor Total', 'Custo Total', 'Lucro Total', 'Custo Unidade']]

# %% [markdown]
# # Filtrando o DataFrame para manter apenas as colunas relevantes

# %%
df2 = df[['Produto','Quantidade', 'Custo Total', 'Lucro Total']]

# %% [markdown]
# # Exibindo os primeiros registros do DataFrame

# %%
print("### DataFrame Inicial ###")
print(df2)
# Out:
# ### DataFrame Inicial ###
#                      Produto  Quantidade  Custo Total  Lucro Total
# 0             Pipoca Pequena        4196      12588.0      31862.0
# 1               água mineral        3727       3727.0      14908.0
# 2          Refrigerante Lata        2477       9908.0      14862.0
# 3               Batata Frita        1921       5763.0      13447.0
# 4               Algodão Doce        1637       2455.5      13604.5
# 5              Pipoca Grande         774       3870.0      11925.0
# 6                     hotdog         726       1452.0       6438.0
# 7               Maçã do Amor         718       2154.0       1957.0
# 8                    CHURROS         638       2552.0       3828.0
# 9                      Pizza         522       2610.0       2610.0
# 10                    pastel         304        912.0       2128.0
# 11               Marshmallow         265       1325.0       1325.0
# 12               Chopp 300ml         203       1624.0        406.0
# 13          Balão Personagem         132        660.0       2070.0
# 14               Chopp 500ml         102        612.0        918.0
# 15  Uva/morango de Chocolate          55        275.0        275.0
# 16               Bolha Bolha          49        392.0        588.0
# 17                   CERVRJA          48        168.0        137.0
# 18                   SUCO 10          40        200.0         80.0
# 19                    Picole          28         56.0         84.0
# 20                Salgadinho          25         50.0         75.0
# 21              Balão de Led          18        108.0        347.0
# 22                   Sorvete           7         35.0         35.0

# %% [markdown]
# # Criando gráficos dos Top 5 produtos em termos de quantidade, Lucro total e valor total

# %% [markdown]
# ### Top 5 produtos mais vendidos

# %%
top5produtos = df.sort_values(by='Quantidade', ascending=False).head(5)
print("\n### Top 5 Produtos Mais Vendidos ###\n")
print(top5produtos)
# Out:
# ### Top 5 Produtos Mais Vendidos ###
#
#              Produto  Quantidade  Valor Total  Custo Total  Lucro Total
# 0     Pipoca Pequena        4196        44450      12588.0      31862.0
# 1       água mineral        3727        18635       3727.0      14908.0
# 2  Refrigerante Lata        2477        24770       9908.0      14862.0
# 3       Batata Frita        1921        19210       5763.0      13447.0
# 4       Algodão Doce        1637        16060       2455.5      13604.5

# %% [markdown]
# ### Top 5 produtos maior faturamento

# %%
top5faturamento = df.sort_values(by='Valor Total', ascending=False).head(5)
print("\n### Top 5 Produtos Maior Faturamento ###\n")
print(top5vendas)
# Out:
# ### Top 5 Produtos Maior Faturamento ###
#
#              Produto  Quantidade  Valor Total  Custo Total  Lucro Total
# 0     Pipoca Pequena        4196        44450      12588.0      31862.0
# 1       água mineral        3727        18635       3727.0      14908.0
# 2  Refrigerante Lata        2477        24770       9908.0      14862.0
# 4       Algodão Doce        1637        16060       2455.5      13604.5
# 3       Batata Frita        1921        19210       5763.0      13447.0

# %% [markdown]
# ### Top 5 produtos mais lucrativos

# %%
top5vendas = df.sort_values(by='Lucro Total', ascending=False).head(5)
print("\n### Top 5 Produtos Mais Lucrativos ###\n")
print(top5vendas)
# Out:
# ### Top 5 Produtos Mais Lucrativos ###
#
#              Produto  Quantidade  Valor Total  Custo Total  Lucro Total
# 0     Pipoca Pequena        4196        44450      12588.0      31862.0
# 1       água mineral        3727        18635       3727.0      14908.0
# 2  Refrigerante Lata        2477        24770       9908.0      14862.0
# 4       Algodão Doce        1637        16060       2455.5      13604.5
# 3       Batata Frita        1921        19210       5763.0      13447.0

# %% [markdown]
# # Criando gráficos de barras para os Top 5 produtos

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
plt.title('Top 5 Produtos Mais Vendidos')
sns.barplot(x='Produto', y='Quantidade', data=top5produtos)
plt.xticks(rotation=45)

plt.subplot(2, 2, 2)
plt.title('Top 5 Produtos Maior Faturamento')
sns.barplot(x='Produto', y='Valor Total', data=top5vendas)
plt.xticks(rotation=45)

plt.subplot(2, 2, 3)
plt.title('Top 5 Produtos Mais Lucrativos')
sns.barplot(x='Produto', y='Lucro Total', data=top5vendas)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Estatísticas descritivas do conjunto de dados

# %%
estatisticas = df.describe()
print("\n### Estatísticas Descritivas ###\n")
print(estatisticas)
# Out:
# ### Estatísticas Descritivas ###
#
#         Quantidade   Valor Total   Custo Total   Lucro Total  Custo Unidade
# count    23.000000     23.000000     23.000000     23.000000      23.000000
# mean    809.217391   7713.304348   2325.934783   5387.369565       4.130435
# std    1196.687168  10920.429926   3210.279421   7913.678710       1.884249
# min       7.000000     70.000000     35.000000     35.000000       1.000000
# 25%      48.500000    502.500000    237.500000    311.000000       3.000000
# 50%     265.000000   2730.000000   1325.000000   1957.000000       4.000000
# 75%     750.000000  11842.500000   2581.000000   9181.500000       5.000000
# max    4196.000000  44450.000000  12588.000000  31862.000000       8.000000

# %% [markdown]
# # Criando boxplots para 'Quantidade' e 'Valor Total'

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.title('Boxplot Quantidade')
plt.boxplot(df['Quantidade'])

plt.subplot(2, 2, 2)
plt.title('Lucro Total')
plt.boxplot(df['Lucro Total'])

plt.subplot(2, 2, 3)
plt.title('Valor Faturado')
plt.boxplot(df['Valor Total'])

plt.subplot(2, 2, 4)
plt.title('Custo Unidade')
plt.boxplot(df['Custo Unidade'])


plt.tight_layout()
plt.show()

# %% [markdown]
# # Criando um gráfico de dispersão entre 'Quantidade' e 'Valor Total'

# %%
plt.figure(figsize=(12, 4))

sns.lmplot(x='Quantidade', y='Valor Total', data=df)
plt.xlabel('Quantidade')
plt.ylabel('Valor Total')
plt.title('Gráfico de Dispersão')
plt.show()
# Out:
# C:\Users\praga\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
